# %%
# 검색어: 테스트

import requests

search = '테스트'
base_url = 'https://openapi.naver.com'
endpoint = '/v1/search/blog.json'
queries  = f'?display=10&start=1&sort=sim&query={search}'
request_url = base_url + endpoint + queries

response = requests.get(request_url, headers={
		'X-Naver-Client-Id': '_ZmCg8dq6yF7ryeYonjh',
		'X-Naver-Client-Secret': 'y4gNuvrnkE',
		'Content-Type': 'application/json'
	})
response.json()
# Out:
# {'lastBuildDate': 'Sun, 24 Mar 2024 17:52:20 +0900',
#  'total': 12685279,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '도봉구 누수탐지 <b>테스트</b> 확인 해결',
#    'link': 'https://blog.naver.com/op7541/223381910499',
#    'description': '그 후 난방관, 온수관 직수관에 공압 <b>테스트</b>를 차례대로 진행했습니다. 공압 검사는 콤프레샤라는 장비를 활용해 내부에 있는 물을 제거해 줍니다. 그 뒤 공기를 주입하여 어떤 배관에서 압력이 변화되는지... ',
#    'bloggername': '태양철거(철거 및 폐기물전문업체)',
#    'bloggerlink': 'blog.naver.com/op7541',
#    'postdate': '20240313'},
#   {'title': '대구수학학원 내신대비 <b>테스트</b> 추천',
#    'link': 'https://blog.naver.com/modellien/223388832742',
#    'description': '저는 중학교 2-1 과정을 응용 레벨로 입학<b>테스트</b>를 치렀고 성적은 24개 문제 중에 16개 정답이었습니다.... 그리고 그 날 진도만 나가지 않고 꼭 <b>테스트</b>를 봤었는데요. 평소에 선생님과 공부하면서 계산 실수를 자주... ',
#    'bloggername': '다재다능한 진다맘의 인생 메뉴얼',
#    'bloggerlink': 'blog.naver.com/modellien',
#    'postdate': '20240319'},
#   {'title': '방이동 수학학원 진도별<b>테스트</b>로 내신UP',
#    'link': 'https://blog.naver.com/mamansiri/223383628840',
#    'description': '방이동 수학학원을 알아볼 때에도 다양한 <b>테스트</b>를 보러 다니면서, 중등 학년 특성상 딱딱한 분위기에... 첫 수업이 시작되면, 실력 진단 <b>테스트</b>를 보게 되는데요. 상담을 통해 아이와 잘 맞을 거 같은 담임... ',
#    'bloggername': '반짝반짝 너와 나',
#    'bloggerlink': 'blog.naver.com/mamansiri',
#    'postdate': '20240314'},
#   {'title': '안양 누수탐지 누수 <b>테스트</b> 했던 현장',
#    'link': 'https://blog.naver.com/nahong123/223383010818',
#    'description': '저희가 누수 <b>테스트</b>와 공사를 진행했던 현장을 사진을 통해서 함께 보면서 이야기해보도록 할게요.... 이곳 윗집은 가정집 이었는데 위로 올라가서 누수 <b>테스트</b>를 진행해보기로 하였답니다. 윗 집으로 올라가서... ',
#    'bloggername': '배관정보통',
#    'bloggerlink': 'blog.naver.com/nahong123',
#    'postdate': '20240314'},
#   {'title': '도봉구 누수탐지 <b>테스트</b> 통해서 해결',
#    'link': 'https://blog.naver.com/hot9676/223382137054',
#    'description': '공압<b>테스트</b>를 하나하나 진행을 해보았네요 공압<b>테스트</b>는 콤프레샤라는 장비를 이용해서 내부에있는 물을 빼내주는데요 그 뒤에 공기를 넣어서 어떤 배관에서 압력변화가 있는지 확인하는 검사입니다 압력이... ',
#    'bloggername': '설비의 모든 것',
#    'bloggerlink': 'blog.naver.com/hot9676',
#    'postdate': '20240313'},
#   {'title': '보쉬 18V 호환 히트건(열풍기) 구입 그리고 간단 <b>테스트</b>',
#    'link': 'https://mindeater.tistory.com/2650',
#    'description': '출력<b>테스트</b> 3. 구입처 자동차 블랙박스를 교체하면서 차창에 붙은 양면테잎 제거 하는데 애를... 출력<b>테스트</b> 본체 라벨에 18~24V, 출력은 300W라고 표기 되어 있어 이에 준하여 파워서플라이 6018로... ',
#    'bloggername': 'HooneyPaPa Life Sketch',
#    'bloggerlink': 'https://mindeater.tistory.com/',
#    'postdate': '20240312'},
#   {'title': '비메모리 반도체 <b>테스트</b> 소켓 업체 ISC (Ai 시대에 승자 될까?)',
#    'link': 'https://blog.naver.com/now_2716/223390537304',
#    'description': '1️⃣ <b>테스트</b> 소켓이란? ▶ 반도체 IC의 양품/불량 여부를 판단하는 전기적 성능 검사 시, 검사... 2️⃣ 실리콘 러버 <b>테스트</b> 소켓은 ISC가 국내 최초 개발, 세계 최초로 양산에 성공한 제품입니다. (2001년에... ',
#    'bloggername': '명토르의 국내주식 추세추종',
#    'bloggerlink': 'blog.naver.com/now_2716',
#    'postdate': '20240322'},
#   {'title': '심리<b>테스트</b>연애 실제로 성공하기',
#    'link': 'https://blog.naver.com/yimjayoung/223390863714',
#    'description': '그중에서도 심리<b>테스트</b>연애 파트를 좋아하는 편인데요. 나이가 들다 보니 이런 게 다 무슨 소용인가 싶기도 하더라고요. 심리<b>테스트</b>연애는 뭐랄까 현실에서 이룰 수가 없어서 허상으로 하는 느낌이잖아요. 물론... ',
#    'bloggername': '하이힐 신고 뛰는 여자',
#    'bloggerlink': 'blog.naver.com/yimjayoung',
#    'postdate': '20240321'},
#   {'title': '코딩<b>테스트</b> 준비 1:1 담임 관리 제도로 꼼꼼한 슈퍼코딩',
#    'link': 'https://blog.naver.com/ryo73003/223385335224',
#    'description': '이미 직장을 가진 사람들도 그만두고 코딩<b>테스트</b> 준비를 해서 취직을 하는 경우도 많다고 하네요.... 그만큼 초창기와 달리 점점 인력이 증가하고 있어서 기업에서도 아무나 뽑는 게 아니라 몇 가지 <b>테스트</b>를... ',
#    'bloggername': '달팽쓰',
#    'bloggerlink': 'blog.naver.com/ryo73003',
#    'postdate': '20240316'},
#   {'title': '중기이유식 33일 :: 땅콩 알러지 <b>테스트</b> 방법. 땅콩버터 먹이기.',
#    'link': 'https://blog.naver.com/nsmung23/223389942263',
#    'description': '세 가지 재료는 6개월 쯤에 계획을 세워봤는데 계란과 밀가루는 빨리 <b>테스트</b>를 했지만 땅콩버터는... 알러지 <b>테스트</b>] 100% 땅콩버터를 준비해요. 버터 묽기를 보면서 꾸덕하다면 분유물을 추가해줘요. 기호에... ',
#    'bloggername': "BBark's Diary",
#    'bloggerlink': 'blog.naver.com/nsmung23',
#    'postdate': '20240320'}]}

# %%
# 검색어: 스타벅스

import requests

search = '스타벅스'
base_url = 'https://openapi.naver.com'
endpoint = '/v1/search/blog.json'
queries  = f'?display=10&start=1&sort=sim&query={search}'
request_url = base_url + endpoint + queries

response = requests.get(request_url, headers={
		'X-Naver-Client-Id': '_ZmCg8dq6yF7ryeYonjh',
		'X-Naver-Client-Secret': 'y4gNuvrnkE',
		'Content-Type': 'application/json'
	})
response.json()
# Out:
# {'lastBuildDate': 'Sun, 24 Mar 2024 17:53:13 +0900',
#  'total': 5596742,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>스타벅스</b> 메뉴 슈크림라떼 칼로리 가격 봄이로구나~',
#    'link': 'https://blog.naver.com/baby0817/223385121778',
#    'description': '<b>스타벅스</b> 메뉴 슈크림라떼 칼로리 가격 봄이로구나! 갑자기 확 오른 기온 덕분에 봄이 왔음을 제대로... <b>스타벅스</b> 메뉴 종류에도 역시나 봄을 알리는 시그니처 음료들이 많이 보여서 오랜만에 봄시즌 메뉴인... ',
#    'bloggername': '축복받은 유전자 완소남매의 엄마표 먹거리',
#    'bloggerlink': 'blog.naver.com/baby0817',
#    'postdate': '20240316'},
#   {'title': '<b>스타벅스</b> 슈크림라떼 아이스 기간 가격 칼로리 카페인 맛',
#    'link': 'https://blog.naver.com/lovableje/223377118529',
#    'description': '넣어볼랑께용 <b>스타벅스</b> 신메뉴 이번 <b>스타벅스</b>의 spring 음료는 총 3가지였어요 1.슈크림 라떼 2.피스타치오크림라떼 3.카스텔라크럼블딸기블렌디드 이 중 2번 피스타치오는 제가 맛보고 난 뒤 후기글을... ',
#    'bloggername': '쯘이의 꽃같은일상',
#    'bloggerlink': 'blog.naver.com/lovableje',
#    'postdate': '20240308'},
#   {'title': '<b>스타벅스</b> 커피그라인더 난 아닌가봐…',
#    'link': 'https://blog.naver.com/jin_archive7/223389511542',
#    'description': '저도 커피를 직접 내려먹을 수 있는 홈카페 제품들을 눈여겨 보고 있다가 최근들어서 입문용 그라인더라는 <b>스타벅스</b>커피그라인더를 구입해봤어요. 원래 <b>스타벅스</b>커피그라인더로 되기 전에 카플라노 그라인더로... ',
#    'bloggername': "jinny's World-☆",
#    'bloggerlink': 'blog.naver.com/jin_archive7',
#    'postdate': '20240321'},
#   {'title': '<b>스타벅스</b> 쿨 라임 피지오 먹어봄',
#    'link': 'https://blog.naver.com/lunasally/223393459634',
#    'description': '할 일은 해야하기에 토요일도 #<b>스타벅스</b>_매장 으로 출근을 했다. 우리 동네 #<b>스타벅스</b> 는 나름 조용해서 좋다. 하루 종일 있다보면 손님이 바글거릴 때도 있지만 대부분은 많이 복잡하지 않다. 특히나 저녁... ',
#    'bloggername': '감사해피 나봉봉',
#    'bloggerlink': 'blog.naver.com/lunasally',
#    'postdate': '20240324'},
#   {'title': '<b>스타벅스</b> 슈크림라떼 커스텀 가격 기간 정보 후기',
#    'link': 'https://blog.naver.com/etienne03/223390576035',
#    'description': '<b>스타벅스</b> 슈크림라떼 커스텀 가격 기간 정보 후기 안녕하세요 바비에요. 요즘 스벅 가면 자연스레... 그래서 오늘도 저는 벤티 사이즈로 마시고 왔는데요 ㅋㅋㅋ 지금부터 <b>스타벅스</b> 슈크림라떼 자세한 기간... ',
#    'bloggername': "Barbie's place",
#    'bloggerlink': 'blog.naver.com/etienne03',
#    'postdate': '20240321'},
#   {'title': '보령 안면도 <b>스타벅스</b> 가장 가까운 대천해수욕장점',
#    'link': 'https://blog.naver.com/melodytravel/223390327520',
#    'description': '다른 데서 돈을 쓰기보다는 쿠폰이 있는 안면도에서 가까운 <b>스타벅스</b>를 찾았어요. 하지만 아쉽게도... <b>스타벅스</b> 대천해수욕장점 주소 : 충남 보령시 머드로 114 영업시간 : 08:00 ~ 21:00(일~목), 22:00(금,토) 주차... ',
#    'bloggername': '멜로디의 스마트한 여행',
#    'bloggerlink': 'blog.naver.com/melodytravel',
#    'postdate': '20240321'},
#   {'title': '3월 도쿄 <b>스타벅스</b> 리저브 로스터리 방문기 및 벚꽃 후기',
#    'link': 'https://blog.naver.com/tlalsguraud/223386523423',
#    'description': '도쿄 여행을 다녀오기 전에 도쿄에 있는 <b>스타벅스</b> 로스터리를 미리 알아보려고 정리 차원에서... 3월 12일에 다녀온 <b>스타벅스</b> 리저브 로스터리 도쿄 포스팅 시작합니다! <b>스타벅스</b> 리저브 로스터리 도쿄 2019.02.... ',
#    'bloggername': '민트의 로그',
#    'bloggerlink': 'blog.naver.com/tlalsguraud',
#    'postdate': '20240319'},
#   {'title': '진해 카페 벚꽃뷰 끝내줄 <b>스타벅스</b> 경화역DT',
#    'link': 'https://blog.naver.com/namheezi/223390848449',
#    'description': '✔️ 경남 창원시 진해구 진해대로 698 진해 카페 <b>스타벅스</b> 경화역점은 기차와 철길, 겹겹이 쌓인... 편하고 만만한 <b>스타벅스</b>에 주차공간도 있고 뷰까지 좋으니 벚꽃 시즌에는 굉장히 북적일 것 같아요. 안쪽에... ',
#    'bloggername': '나미의 하루하루',
#    'bloggerlink': 'blog.naver.com/namheezi',
#    'postdate': '20240321'},
#   {'title': '일본 <b>스타벅스</b> 2024 벚꽃 시즌 엠디 MD &amp; 개화시기',
#    'link': 'https://blog.naver.com/piil/223391206126',
#    'description': '일본 <b>스타벅스</b> 2024 시즌 MD &amp; 개화시기 여행일자 2024.02 바야흐로 벚꽃여행 시즌입니다~ 우리나라도... 쇼핑하다가 <b>스타벅스</b>를 들렀어요 시모노세키 항은 작지만 역에는 없는 게 없답니다~ 도착하자마자 놀라웠던... ',
#    'bloggername': '세상구경꾼 필의 세상탐구생활',
#    'bloggerlink': 'blog.naver.com/piil',
#    'postdate': '20240322'},
#   {'title': '세부 아얄라몰 <b>스타벅스</b> :: 쇼핑, 환전',
#    'link': 'https://blog.naver.com/jin_1021/223386074342',
#    'description': '제일 처음 들른 곳은 바로 <b>스타벅스</b>였어요. 몇 층에 있는지는 정확히 기억나지 않지만, 건물의 맨 위쪽... <b>스타벅스</b>에서 구입했지만 생각보다 가격이 매우 저렴해서 놀랐어요. 우리 일행은 총 4개의 머그컵과... ',
#    'bloggername': '행복한 상상',
#    'bloggerlink': 'blog.naver.com/jin_1021',
#    'postdate': '20240317'}]}

# %%
# 검색어: 스타벅스

import requests

search = '스타벅스'
base_url = 'https://openapi.naver.com'
endpoint = '/v1/search/blog.json'
queries  = f'?display=10&start=1&sort=sim&query={search}'
request_url = base_url + endpoint + queries

response = requests.get(request_url, headers={
		'X-Naver-Client-Id': '_ZmCg8dq6yF7ryeYonjh',
		'X-Naver-Client-Secret': 'y4gNuvrnkE',
		'Content-Type': 'application/json'
	})
result = response.json()

filtered = []
for item in result["items"]:
	filtered.append(item["bloggername"])

filtered
# Out:
# ['축복받은 유전자 완소남매의 엄마표 먹거리',
#  '쯘이의 꽃같은일상',
#  "jinny's World-☆",
#  '감사해피 나봉봉',
#  "Barbie's place",
#  '멜로디의 스마트한 여행',
#  '민트의 로그',
#  '나미의 하루하루',
#  '세상구경꾼 필의 세상탐구생활',
#  '행복한 상상']

# %%
# 검색어: 입력받기

import requests

search = str(input('검색어를 입력하세요: '))
base_url = 'https://openapi.naver.com'
endpoint = '/v1/search/blog.json'
queries  = f'?display=10&start=1&sort=sim&query={search}'
request_url = base_url + endpoint + queries

response = requests.get(request_url, headers={
		'X-Naver-Client-Id': '_ZmCg8dq6yF7ryeYonjh',
		'X-Naver-Client-Secret': 'y4gNuvrnkE',
		'Content-Type': 'application/json'
	})
result = response.json()

filtered = []
for item in result['items']:
  filtered.append(item['title'])
  
filtered
# Out:
# ['키즈카페 있는 호텔 가평 <b>마이다스</b>호텔 후기',
#  '가평 <b>마이다스</b>호텔 리조트 숙박 아기랑호캉스 조식 레스토랑',
#  '가평 <b>마이다스</b> 호텔 숙박 후기 -',
#  '이천<b>마이다스</b>cc(<b>마이다스</b>레이크이천) 올림프스=&gt;타이탄코스... ',
#  '청평<b>마이다스</b>cc회원권 2가지 소개합니다',
#  '<b>마이다스</b>호텔 키즈잼 북한강보팅 체험 후기',
#  '전남 여수 예술랜드 티켓 입장료 <b>마이다스</b>의 손 가볼만한곳',
#  '가평 <b>마이다스</b>호텔 글램핑 바베큐 석식 BBQ 후기',
#  '가평 <b>마이다스</b> 호텔 듀플렉스, 디오니소스 식당(조식), 키즈잼... ',
#  '이천 <b>마이다스</b> 레이크 CC 골프장 라운딩 그늘집 후기']
